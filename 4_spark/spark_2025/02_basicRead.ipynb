# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()
# Out:
# 25/03/24 01:45:42 WARN Utils: Your hostname, Snehils-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 192.168.29.183 instead (on interface en0)
# 25/03/24 01:45:42 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/24 01:45:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# read a file as text
df = spark.read.text('01_quickstart.ipynb')

# %%
df.show()
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |                   {|
# |          "cells": [|
# |                   {|
# |   "cell_type": "...|
# |   "execution_cou...|
# |     "metadata": {},|
# |      "outputs": [],|
# |         "source": [|
# |    "import pyspa...|
# |    "from pyspark...|
# |    "import panda...|
# |      "import re,os"|
# |                   ]|
# |                  },|
# |                   {|
# |   "cell_type": "...|
# |   "execution_cou...|
# |     "metadata": {},|
# |        "outputs": [|
# |                   {|
# +--------------------+
# only showing top 20 rows

# %%
# show top 10 rows, untruncated
df.show(10,truncate=False)
# Out:
# +---------------------------------------------------+
# |value                                              |
# +---------------------------------------------------+
# |{                                                  |
# | "cells": [                                        |
# |  {                                                |
# |   "cell_type": "code",                            |
# |   "execution_count": 1,                           |
# |   "metadata": {},                                 |
# |   "outputs": [],                                  |
# |   "source": [                                     |
# |    "import pyspark\n",                            |
# |    "from pyspark.sql import types,SparkSession\n",|
# +---------------------------------------------------+
# only showing top 10 rows

# %%
# number of rows
df.count()
# Out:
# 212
